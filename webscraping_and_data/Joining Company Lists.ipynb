# %%
import pandas as pd

# %%
data = pd.read_csv('companylist.csv', sep =',')
data
# Out:
#      Symbol                                    Name  LastSale MarketCap  \
# 0       TXG                      10x Genomics, Inc.    82.380     $8.1B
# 1        YI                               111, Inc.     7.000  $576.52M
# 2       PIH  1347 Property Insurance Holdings, Inc.     4.590   $27.85M
# 3     PIHPP  1347 Property Insurance Holdings, Inc.    24.625   $17.24M
# 4      TURN                180 Degree Capital Corp.     1.720   $53.53M
# ...     ...                                     ...       ...       ...
# 3601     ZS                           Zscaler, Inc.    99.310   $12.96B
# 3602   ZUMZ                             Zumiez Inc.    29.460   $749.2M
# 3603   ZYNE           Zynerba Pharmaceuticals, Inc.     5.410  $134.98M
# 3604   ZYXI                             Zynex, Inc.    21.430  $711.32M
# 3605   ZNGA                              Zynga Inc.     8.970    $8.58B
#
#       IPOyear             Sector  \
# 0      2019.0      Capital Goods
# ...

# %%
data2 = pd.read_csv('companylist-2.csv', sep =',')
data2
# Out:
#     Symbol                                               Name  LastSale  \
# 0     XXII                            22nd Century Group, Inc    0.7906
# 1      FAX              Aberdeen Asia-Pacific Income Fund Inc    3.8000
# 2      IAF                 Aberdeen Australia Equity Fund Inc    4.6600
# 3      AEF  Aberdeen Emerging Markets Equity Income Fund, ...    6.1700
# 4      FCO                  Aberdeen Global Income Fund, Inc.    6.2700
# ..     ...                                                ...       ...
# 288    WYY                              WidePoint Corporation    0.5521
# 289    WTT                      Wireless Telecom Group,  Inc.    1.2000
# 290   XTNT                       Xtant Medical Holdings, Inc.    1.2800
# 291   ZDGE                                        Zedge, Inc.    1.1100
# 292    ZOM                     Zomedica Pharmaceuticals Corp.    0.1750
#
#     MarketCap  IPOyear                 Sector  \
# 0    $109.78M      NaN  Consumer Non-Durables
# ...

# %%
data3 = pd.read_csv('companylist-3.csv', sep =',')

# %%
data_company = pd.concat([data, data2, data3])

# %%
data_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6994 entries, 0 to 3094
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         6994 non-null   object
#  1   Name           6994 non-null   object
#  2   LastSale       6826 non-null   float64
#  3   MarketCap      5907 non-null   object
#  4   IPOyear        3226 non-null   float64
#  5   Sector         5315 non-null   object
#  6   industry       5315 non-null   object
#  7   Summary Quote  6994 non-null   object
#  8   Unnamed: 8     0 non-null      float64
# dtypes: float64(3), object(6)
# memory usage: 546.4+ KB

# %%
len(data_company.Symbol.drop_duplicates())
# Out:
# 6979

# %%
len(data_company.Symbol)
# Out:
# 6994

# %%
ticker_company = dados_company.Symbol.drop_duplicates()

# %%
ticker_company
# Out:
# 0         TXG
# 1          YI
# 2         PIH
# 3       PIHPP
# 4        TURN
#         ...
# 3090      ZBH
# 3091      ZTS
# 3092      ZTO
# 3093      ZUO
# 3094     ZYME
# Name: Symbol, Length: 6979, dtype: object

# %%
duplicate_company_ticket = data_company[dados_company.duplicated(['Symbol'])] #take the duplicated tickets and show me which are
print(duplicateDFRow)
# Out:
#      Symbol                                 Name  LastSale MarketCap  IPOyear  \
# 72     CDOR       Condor Hospitality Trust, Inc.    5.0300   $60.38M      NaN
# 168    LLEX                   Lilis Energy, Inc.    0.2199   $20.98M      NaN
# 4      EGHT                              8x8 Inc   14.7400    $1.53B      NaN
# 113    AMBC          Ambac Financial Group, Inc.   14.9100  $682.57M      NaN
# 120    AMOV        America Movil, S.A.B. de C.V.   14.1900    $46.8B      NaN
# 355    GOLD             Barrick Gold Corporation   23.2900   $41.41B      NaN
# 776    CNMD                   CONMED Corporation   81.7600    $2.33B   1987.0
# 1470   INFO                      IHS Markit Ltd.   73.5600   $29.34B   1996.0
# 1991   NCLH  Norwegian Cruise Line Holdings Ltd.   22.4300    $5.75B      NaN
# 2188   PGTI                PGT Innovations, Inc.   16.1500  $951.65M   2006.0
# 2261   PRMW              Primo Water Corporation   12.4400    $1.99B      NaN
# ...

# %%
list_company = list(duplicate_company_ticket['Symbol'])

# %%
## See if there is a diference in the duplicated tickets

# %%
for ticket in list_company:
    select = (data_company['Symbol'] == ticket)
    company = data_company[select]
    print(company)
# Out:
#     Symbol                            Name  LastSale MarketCap  IPOyear  \
# 773   CDOR  Condor Hospitality Trust, Inc.      5.03   $60.38M      NaN
# 72    CDOR  Condor Hospitality Trust, Inc.      5.03   $60.38M      NaN
#
#                 Sector                       industry  \
# 773  Consumer Services  Real Estate Investment Trusts
# 72   Consumer Services  Real Estate Investment Trusts
#
#                           Summary Quote  Unnamed: 8
# 773  https://old.nasdaq.com/symbol/cdor         NaN
# 72   https://old.nasdaq.com/symbol/cdor         NaN
#      Symbol                Name  LastSale MarketCap  IPOyear  Sector  \
# 2050   LLEX  Lilis Energy, Inc.    0.2199   $20.98M      NaN  Energy
# 168    LLEX  Lilis Energy, Inc.    0.2199   $20.98M      NaN  Energy
#
#                   industry                       Summary Quote  Unnamed: 8
# 2050  Oil & Gas Production  https://old.nasdaq.com/symbol/llex         NaN
# ...

# %%
#Delete de duplicated tickets

# %%
data_company.drop_duplicates(subset = ['Symbol'] , inplace = True)

# %%
data_company
# Out:
#      Symbol                                    Name  LastSale MarketCap  \
# 0       TXG                      10x Genomics, Inc.    82.380     $8.1B
# 1        YI                               111, Inc.     7.000  $576.52M
# 2       PIH  1347 Property Insurance Holdings, Inc.     4.590   $27.85M
# 3     PIHPP  1347 Property Insurance Holdings, Inc.    24.625   $17.24M
# 4      TURN                180 Degree Capital Corp.     1.720   $53.53M
# ...     ...                                     ...       ...       ...
# 3090    ZBH            Zimmer Biomet Holdings, Inc.   137.400   $28.41B
# 3091    ZTS                             Zoetis Inc.   141.010   $66.97B
# 3092    ZTO               ZTO Express (Cayman) Inc.    34.560   $27.09B
# 3093    ZUO                             Zuora, Inc.    12.750    $1.48B
# 3094   ZYME                          Zymeworks Inc.    36.600    $1.44B
#
#       IPOyear          Sector  \
# 0      2019.0   Capital Goods
# 1      2018.0     Health Care
# ...

# %%
list(data_company.columns)
# Out:
# ['Symbol',
#  'Name',
#  'LastSale',
#  'MarketCap',
#  'IPOyear',
#  'Sector',
#  'industry',
#  'Summary Quote',
#  'Unnamed: 8']

# %%
del data_company['Unnamed: 8']

# %%
data_company
# Out:
#      Symbol                                    Name  LastSale MarketCap  \
# 0       TXG                      10x Genomics, Inc.    82.380     $8.1B
# 1        YI                               111, Inc.     7.000  $576.52M
# 2       PIH  1347 Property Insurance Holdings, Inc.     4.590   $27.85M
# 3     PIHPP  1347 Property Insurance Holdings, Inc.    24.625   $17.24M
# 4      TURN                180 Degree Capital Corp.     1.720   $53.53M
# ...     ...                                     ...       ...       ...
# 3090    ZBH            Zimmer Biomet Holdings, Inc.   137.400   $28.41B
# 3091    ZTS                             Zoetis Inc.   141.010   $66.97B
# 3092    ZTO               ZTO Express (Cayman) Inc.    34.560   $27.09B
# 3093    ZUO                             Zuora, Inc.    12.750    $1.48B
# 3094   ZYME                          Zymeworks Inc.    36.600    $1.44B
#
#       IPOyear          Sector  \
# 0      2019.0   Capital Goods
# 1      2018.0     Health Care
# ...

# %%
data_company.to_csv('data_company.csv', sep = ',')

# %%
data_company.to_excel('data_company.xlsx')

# %%
data_company['Sector'].drop_duplicates()
# Out:
# 0              Capital Goods
# 1                Health Care
# 2                    Finance
# 5          Consumer Services
# 10                Technology
# 13             Miscellaneous
# 26                    Energy
# 37                       NaN
# 48     Consumer Non-Durables
# 65          Public Utilities
# 67          Basic Industries
# 109           Transportation
# 196        Consumer Durables
# Name: Sector, dtype: object

# %%
data_company[data_company['Sector'].isnull()]
# Out:
#      Symbol                                               Name  LastSale  \
# 37     ACCP                           Accelerated Pharma, Inc.       NaN
# 72     DWEQ  AdvisorShares Dorsey Wright Alpha Equal Weight...   20.0204
# 73     DWAW  AdvisorShares Dorsey Wright FSM All Cap World ETF   27.5945
# 74     DWUS        AdvisorShares Dorsey Wright FSM US Core ETF   26.5847
# 75     DWMC          AdvisorShares Dorsey Wright Micro-Cap ETF   20.8509
# ...     ...                                                ...       ...
# 3038    MNP        Western Asset Municipal Partners Fund, Inc.   14.0100
# 3039    GFY    Western Asset Variable Rate Strategic Fund Inc.   15.3300
# 3040    WIW  Western Asset/Claymore U.S Treasury Inflation ...   10.7900
# 3041    WIA  Western Asset/Claymore U.S. Treasury Inflation...   11.5700
# 3074   XFLT  XAI Octagon Floating Rate & Alternative Income...    5.5000
#
#      MarketCap  IPOyear Sector industry                       Summary Quote
# ...
